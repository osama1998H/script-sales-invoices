# %%
import pandas as pd 
import numpy as np

# %%
file_name = '1_invoice_test.xlsx'
# 1_invoice_test.xlsx

# %%
df = pd.read_excel(file_name, header=0)
df.head(3)
# Out:
#   Company       Date Currency  Exchange Rate        Price List  \
# 0    AOAI 2021-12-22      USD              1  Standard Selling
# 1    AOAI 2021-12-22      USD              1  Standard Selling
# 2    AOAI 2021-12-22      USD              1  Standard Selling
#
#   Price List Currency  Price List Exchange Rate  Net Total (Company Currency)  \
# 0                 USD                         1                         527.8
# 1                 USD                         1                         527.8
# 2                 USD                         1                         527.8
#
#    Grand Total (Company Currency)  Grand Total  ... Service End Date (Items)  \
# 0                           527.8        527.8  ...                      NaN
# 1                           527.8        527.8  ...                      NaN
# 2                           527.8        527.8  ...                      NaN
#
#   Weight Per Unit (Items) Total Weight (Items) Weight UOM (Items)  \
# ...

# %%
df.at[1, 'Company'] = ''

# %%
df.head()
# Out:
#   Company       Date Currency  Exchange Rate        Price List  \
# 0    AOAI 2021-12-22      USD              1  Standard Selling
# 1         2021-12-22      USD              1  Standard Selling
# 2    AOAI 2021-12-22      USD              1  Standard Selling
#
#   Price List Currency  Price List Exchange Rate  Net Total (Company Currency)  \
# 0                 USD                         1                         527.8
# 1                 USD                         1                         527.8
# 2                 USD                         1                         527.8
#
#    Grand Total (Company Currency)  Grand Total  ... Service End Date (Items)  \
# 0                           527.8        527.8  ...                      NaN
# 1                           527.8        527.8  ...                      NaN
# 2                           527.8        527.8  ...                      NaN
#
#   Weight Per Unit (Items) Total Weight (Items) Weight UOM (Items)  \
# ...

# %%
df.to_excel(file_name,  header=True, index=False)

# %%
df.at[(1,2), 'Company'] = ''

# %%
df.head()
# Out:
#   Company       Date Currency  Exchange Rate        Price List  \
# 0    AOAI 2021-12-22      USD              1  Standard Selling
# 1         2021-12-22      USD              1  Standard Selling
# 2         2021-12-22      USD              1  Standard Selling
#
#   Price List Currency  Price List Exchange Rate  Net Total (Company Currency)  \
# 0                 USD                         1                         527.8
# 1                 USD                         1                         527.8
# 2                 USD                         1                         527.8
#
#    Grand Total (Company Currency)  Grand Total  ... Service End Date (Items)  \
# 0                           527.8        527.8  ...                      NaN
# 1                           527.8        527.8  ...                      NaN
# 2                           527.8        527.8  ...                      NaN
#
#   Weight Per Unit (Items) Total Weight (Items) Weight UOM (Items)  \
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Date', 'Currency', 'Exchange Rate', 'Price List',
#        'Price List Currency', 'Price List Exchange Rate',
#        'Net Total (Company Currency)', 'Grand Total (Company Currency)',
#        'Grand Total', 'Debit To', 'Customer', 'Customer Name',
#        'Payment Due Date', 'Cost Center', 'Customer Address', 'Address',
#        'Mobile No', 'Territory', 'Total Quantity', 'Total (Company Currency)',
#        'Total', 'Net Total', 'Apply Additional Discount On',
#        'Additional Discount Amount (Company Currency)',
#        'Additional Discount Percentage', 'Additional Discount Amount',
#        'Against Income Account', 'ID (Items)', 'Item Name (Items)',
#        'Description (Items)', 'UOM (Items)', 'UOM Conversion Factor (Items)',
#        'Rate (Items)', 'Amount (Items)', 'Rate (Company Currency) (Items)',
#        'Amount (Company Currency) (Items)', 'Income Account (Items)',
#        'Cost Center (Items)', 'Barcode (Items)', 'Item (Items)',
# ...

# %%
for column in df.columns:
    print(column)
# Out:
# Company
# Date
# Currency
# Exchange Rate
# Price List
# Price List Currency
# Price List Exchange Rate
# Net Total (Company Currency)
# Grand Total (Company Currency)
# Grand Total
# Debit To
# Customer
# Customer Name
# Payment Due Date
# Cost Center
# Customer Address
# Address
# Mobile No
# Territory
# Total Quantity
# Total (Company Currency)
# Total
# Net Total
# Apply Additional Discount On
# Additional Discount Amount (Company Currency)
# Additional Discount Percentage
# Additional Discount Amount
# Against Income Account
# ID (Items)
# Item Name (Items)
# Description (Items)
# UOM (Items)
# UOM Conversion Factor (Items)
# Rate (Items)
# Amount (Items)
# Rate (Company Currency) (Items)
# Amount (Company Currency) (Items)
# Income Account (Items)
# Cost Center (Items)
# Barcode (Items)
# Item (Items)
# Customer's Item Code (Items)
# Item Group (Items)
# Brand Name (Items)
# Image (Items)
# Quantity (Items)
# Stock UOM (Items)
# Qty as per Stock UOM (Items)
# ...
